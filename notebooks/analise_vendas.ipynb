# %% [markdown]
# ### Etapa 1 - Importação dos dados
# - Carregar o arquivo CSV utilizando Pandas.
# - Verificar quantidade de linhas, colunas e tipos de dados.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/dataset_analise_vendas.csv")
df
# Out:
#      ID_Venda        Data               Produto    Categoria  Quantidade  \
# 0           1  2025-07-19         Cadeira Gamer       Móveis           2
# 1           2  2025-08-18              Notebook  Eletrônicos           5
# 2           3  2025-08-13  Livro Banco de Dados       Livros           1
# 3           4  2025-04-28      Teclado Mecânico  Eletrônicos           1
# 4           5  2025-01-19       Mesa Escritório       Móveis           4
# ..        ...         ...                   ...          ...         ...
# 495       496  2025-06-01            Smartphone  Eletrônicos           1
# 496       497  2025-04-08          Curso Online     Educação           4
# 497       498  2025-01-13       Mesa Escritório       Móveis           2
# 498       499  2025-12-16              Notebook  Eletrônicos           5
# 499       500  2025-01-14         Cadeira Gamer       Móveis           2
#
#      Preco_Unitario  Valor_Total   Cliente Estado
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_Venda        500 non-null    int64
#  1   Data            500 non-null    str
#  2   Produto         500 non-null    str
#  3   Categoria       500 non-null    str
#  4   Quantidade      500 non-null    int64
#  5   Preco_Unitario  500 non-null    int64
#  6   Valor_Total     500 non-null    int64
#  7   Cliente         500 non-null    str
#  8   Estado          500 non-null    str
# dtypes: int64(4), str(5)
# memory usage: 54.9 KB
